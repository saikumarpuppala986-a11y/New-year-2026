# %% [markdown]
# <a href="https://colab.research.google.com/github/saikumarpuppala986-a11y/New-year-2026/blob/main/NewBatch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installation of python
# why python becase python has lot's of features to use(Esy to use,learn,strong library)
# use of python(website,app,AI, ML etc...)
# frameworks of python ()
#### python(Engine of a car) +
# framework(body of a car)-Jupyter/VS Code/Spyder/google colab(online).....


# Data types in python
# how python actually runs on code

# %%
10 - 100
1000
# Out:
# 1000

# %%
print('Germany')
print('London')
# Out:
# Germany
# London

# %%
# Data Types
# 10,100,1837 -> Number --> integer(int)
# 19.3, 438.4 -> decimals -> float(float)
# abc, Germany -> text -> string(str)
# True, false -> boolen -> boolean(bool)
# 2+4i, 3-5j -> complex -> complex(complex)

# %%
type(47.3)
# Out:
# float

# %%
10//5
# Out:
# 2

# %%
# Storing data in variables
a = 20
b = 3
result = a * b

print("The result of multiplication is:")
print(result)
# Out:
# The result of multiplication is:
# 60

# %%
# Making the code interactive
name = input("Enter your name: ")
age = input("Enter your age: ")

print("Hello " + name + "! You are " + age + " years old.")
# Out:
# Enter your name: Saikumar
# Enter your age: 18
# Hello Saikumar ! You are 18 years old.
